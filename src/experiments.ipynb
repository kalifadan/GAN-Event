# %% [markdown]
# ## Leveraging World Events to Predict E-Commerce Consumer Demand under Anomaly

# %%
import sys
sys.path.append('.')
sys.path.append('../')
import os 
import os.path as path
import datetime
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm    
import darts
from darts import TimeSeries
import cufflinks as cf
cf.go_offline()
from plotly.offline import plot, download_plotlyjs, init_notebook_mode, plot, iplot
from IPython.display import display, Math, Markdown
from IPython.display import display, Markdown, clear_output
import ipywidgets as widgets
# %load_ext autoreload
# %autoreload 2
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Import Functions

# %%
import config as proj_config
cache_path = proj_config.CACHE_DIR
data_path = proj_config.DATA_DIR
events_data_path = proj_config.EVENTS_DATASET_DIR
categories_path = cache_path + '/categories_events/'

# %%
from demand_prediction.general_functions import get_file_path, get_df_table, load_table_cache, save_table_cache, get_pred_dates
from demand_prediction.dataset_functions import split_data, create_events_df
from demand_prediction.ts_models import train_models, test_models, save_model, load_model
from demand_prediction.events_models import load_events_model, save_events_model, calc_events_ts
from demand_prediction.neural_prophet_model import NeuralProphetEvents, reformat_events_name, get_events_for_neural_prophet, get_neural_prophet_results
from demand_prediction.lstm_models import get_lstm_results
from demand_prediction.tcn_models import get_tcn_results
# from demand_prediction.results_functions import get_combine_results, get_paper_results, get_all_k_metrics
# Out:
# Global seed set to 0

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Events

# %%
world_events = get_df_table("events/world_events_dataset_from_1980") 
world_events.head()
# Out:
# Total data size:  16766
#                                wiki_name        date  \
# 0  1980 Avon Championships of Cincinnati  1980-01-07
# 1      1980 Avon Championships of Kansas  1980-01-14
# 2                   1980 Birmingham Open  1980-01-14
# 3     1980 Avon Championships of Chicago  1980-01-21
# 4   1980 CONMEBOL Pre-Olympic Tournament  1980-01-23
#
#                     country          Category High-Category  ref_num  \
# 0  United States of America  TennisTournament   SportsEvent        1
# 1  United States of America  TennisTournament   SportsEvent        3
# 2  United States of America  TennisTournament   SportsEvent        4
# 3  United States of America  TennisTournament   SportsEvent        2
# 4                  Colombia  SoccerTournament   SportsEvent       15
#
#    avg_num_views                                          embedding
# 0       1.923165  [-0.7737418, 0.44452286, 0.44949022, -0.293493...
# 1       2.240642  [-0.7737418, 0.44452286, 0.44949022, -0.293493...
# 2       2.239492  [-0.3976065, -0.59886205, 1.0677863, 0.0126197...
# 3       2.626353  [-0.7737418, 0.44452286, 0.44949022, -0.293493...
# 4       3.678718  [-0.84798235, -0.18931623, -0.30384776, -0.392...

# %% [markdown]
# ## Ecommerce

# %% [markdown]
# Use the following random time series as an expample or provide your own time series.
# Please make sure that the ts is a DataFrame that contains one column which is the product sales, and the index is the dates.

# %%
dates_example = pd.date_range("2018-06-01", "2020-12-31",freq='d')
values_example = np.random.randint(100,2000,size=(len(dates_example)))
categ_data = pd.DataFrame({'date': dates_example, 'Quantity': values_example})
categ_data.index = categ_data['date']
categ_data = categ_data.drop(columns=['date'])

# %% [markdown]
# ## Time Series

# %%
leaf_name = 'Football Cards'

# %%
categ_data.iplot(title=leaf_name, xTitle='Date', yTitle='Sales', theme='white', colors=['steelblue'])
# Out:
# <div>                            <div id="46273db9-6250-437a-a3cd-ed08696335d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("46273db9-6250-437a-a3cd-ed08696335d8")) {                    Plotly.newPlot(                        "46273db9-6250-437a-a3cd-ed08696335d8",                        [{"line": {"color": "rgba(70, 130, 180, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Quantity", "text": "", "type": "scatter", "x": ["2018-06-01", "2018-06-02", "2018-06-03", "2018-06-04", "2018-06-05", "2018-06-06", "2018-06-07", "2018-06-08", "2018-06-09", "2018-06-10", "2018-06-11", "2018-06-12", "2018-06-13", "2018-06-14", "2018-06-15", "2018-06-16", "2018-06-17", "2018-06-18", "2018-06-19", "2018-06-20", "2018-06-21", "2018-06-22", "2018-06-23", "2018-06-24", "2018-06-25", "2018-06-26", "2018-06-27", "2018-06-28", "2018-06-29", "2018-06-30", "2018-07-01", "2018-07-02", "2018-07-03", "2018-07-04", "2018-07-05", "2018-07-06", "2018-07-07", "2018-07-08", "2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-14", "2018-07-15", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-21", "2018-07-22", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-28", "2018-07-29", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-04", "2018-08-05", "2018-08-06", "2018-08-07", "2018-08-08", "2018-08-09", "2018-08-10", "2018-08-11", "2018-08-12", "2018-08-13", "2018-08-14", "2018-08-15", "2018-08-16", "2018-08-17", "2018-08-18", "2018-08-19", "2018-08-20", "2018-08-21", "2018-08-22", "2018-08-23", "2018-08-24", "2018-08-25", "2018-08-26", "2018-08-27", "2018-08-28", "2018-08-29", "2018-08-30", "2018-08-31", "2018-09-01", "2018-09-02", "2018-09-03", "2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-09", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-16", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-21", "2018-09-22", "2018-09-23", "2018-09-24", "2018-09-25", "2018-09-26", "2018-09-27", "2018-09-28", "2018-09-29", "2018-09-30", "2018-10-01", "2018-10-02", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-12", "2018-10-13", "2018-10-14", "2018-10-15", "2018-10-16", "2018-10-17", "2018-10-18", "2018-10-19", "2018-10-20", "2018-10-21", "2018-10-22", "2018-10-23", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-27", "2018-10-28", "2018-10-29", "2018-10-30", "2018-10-31", "2018-11-01", "2018-11-02", "2018-11-03", "2018-11-04", "2018-11-05", "2018-11-06", "2018-11-07", "2018-11-08", "2018-11-09", "2018-11-10", "2018-11-11", "2018-11-12", "2018-11-13", "2018-11-14", "2018-11-15", "2018-11-16", "2018-11-17", "2018-11-18", "2018-11-19", "2018-11-20", "2018-11-21", "2018-11-22", "2018-11-23", "2018-11-24", "2018-11-25", "2018-11-26", "2018-11-27", "2018-11-28", "2018-11-29", "2018-11-30", "2018-12-01", "2018-12-02", "2018-12-03", "2018-12-04", "2018-12-05", "2018-12-06", "2018-12-07", "2018-12-08", "2018-12-09", "2018-12-10", "2018-12-11", "2018-12-12", "2018-12-13", "2018-12-14", "2018-12-15", "2018-12-16", "2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02 ...

# %% [markdown]
# ### Events Dataset

# %%
data = create_events_df(categ_data, world_events, emb_only=True)
events_dates = list(set(data['date']))

# %%
# Not Relevant
peaks_data = categ_data.copy()
peaks_data = peaks_data.rename(columns={'Quantity': 'peak'})
peaks_data['peak'] = None

# %% [markdown]
# ### Hyper-Parameters

# %%
ts_cache = True 
neural_cache = True
lstm_cache = True
lstm_df_cache = True
tcn_cache = True
tcn_df_cache = True
results_cache = True 

n_in = 365
window_size = 2    
prediction_time = 30   

device = 'cpu'  # 'cuda:2'

# %%
final_list = []
total_pred = pd.DataFrame()

start_pred_list = get_pred_dates('2020-01-01', '2021-01-01')[0:1]

for start_pred_time in tqdm(start_pred_list): 
    pred_path = cache_path + "/saved_results/final_results_" + leaf_name + "_" + str(start_pred_time) + "_predictions"
    if pred_path and os.path.isfile(pred_path):
        total_pred = pd.read_pickle(pred_path)
        
    else:
        X_train, X_test = split_data(data, start_pred_time)    
        time_series = TimeSeries.from_dataframe(categ_data, value_cols='Quantity')    
        train, test_ts = time_series.split_before(pd.Timestamp(start_pred_time))
        test = test_ts[:prediction_time]
        events_all = pd.concat([X_train, X_test])
        train_df, test_df = train.pd_dataframe(), test.pd_dataframe()
        train_dates, test_dates = train_df.index.values, test_df.index.values
         
        res_prediction = test_models(test, test_name=leaf_name, start_pred_time=start_pred_time, train=train, use_cache=ts_cache)        
        lstm_predictions = get_lstm_results(train, test, train_df, test_df, events_all, start_pred_time, leaf_name, peaks_data, n_in, window_size, events_dates, device, lstm_df_cache, lstm_cache)                   
        tcn_predictions = get_tcn_results(train, test, train_df, test_df, events_all, start_pred_time, leaf_name, peaks_data, n_in, window_size, events_dates, device, tcn_df_cache, tcn_cache)        
        neural_predictions = get_neural_prophet_results(train, test, events_all, leaf_name, peaks_data, events_dates, start_pred_time, neural_cache)
        
        total_pred = pd.concat([total_pred, pd.concat([res_prediction, lstm_predictions, tcn_predictions, neural_predictions], axis=1)])
        total_pred.to_pickle(pred_path) 
                
    final_list.append(final_res)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Train size: 1063  - Test size: 304
# Model:  ARIMA
# Loaded model from cache.
# <div>                            <div id="531e7b43-0334-4c1f-9493-9c6f256cdc1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("531e7b43-0334-4c1f-9493-9c6f256cdc1f")) {                    Plotly.newPlot(                        "531e7b43-0334-4c1f-9493-9c6f256cdc1f",                        [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Real Quantity", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30"], "y": [455, 937, 234, 103, 1350, 989, 780, 544, 1541, 1408, 936, 126, 836, 348, 465, 1325, 1561, 297, 1029, 1771, 737, 706, 172, 346, 952, 1259, 1831, 313, 1599, 1744]}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "ARIMA", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30"], "y": [1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476, 1012.4547945205476]}],                        {"legend": {"bgcolor": "#FFFFFF", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#FFFFFF", "plot_bgcolor": "#FFFFFF", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, ...
# Model:  Prophet
# Loaded model from cache.
# <div>                            <div id="c3d3223f-5576-4682-9029-393ed103d550" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("c3d3223f-5576-4682-9029-393ed103d550")) {                    Plotly.newPlot(                        "c3d3223f-5576-4682-9029-393ed103d550",                        [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Real Quantity", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30"], "y": [455, 937, 234, 103, 1350, 989, 780, 544, 1541, 1408, 936, 126, 836, 348, 465, 1325, 1561, 297, 1029, 1771, 737, 706, 172, 346, 952, 1259, 1831, 313, 1599, 1744]}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Prophet", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30"], "y": [989.3648446239579, 999.8134099662012, 1002.9247211967903, 1045.5197933975292, 1154.9669446037449, 1055.538004867693, 956.4436761429561, 1000.25555753742, 1000.3989708695816, 1003.5102821001699, 1046.1053543009978, 1155.5525055070568, 1056.1235657709162, 957.0292370462034, 1000.841118440652, 1000.9845317729623, 1004.0958430035896, 1046.6909152045496, 1156.1380664105384, 1232.0520067567352, 957.614797949682, 1001.4266793440339, 1001.5700926763432, 1004.6814039069992, 1047.276476108018, 1156.7236273139122, 1057.2946875775851, 958.2003588530448, 1002.0122402476096, 1002.1556535797829]}],                        {"legend": {"bgcolor": "#FFFFFF", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#FFFFFF", "plot_bgcolor": "#FFFFFF", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorsca ...
# Model:  NeuralProphet
# Loaded model from cache.
# <div>                            <div id="0595846d-d8ac-40f7-b059-82e19d628fb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("0595846d-d8ac-40f7-b059-82e19d628fb3")) {                    Plotly.newPlot(                        "0595846d-d8ac-40f7-b059-82e19d628fb3",                        [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Real Quantity", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30"], "y": [455, 937, 234, 103, 1350, 989, 780, 544, 1541, 1408, 936, 126, 836, 348, 465, 1325, 1561, 297, 1029, 1771, 737, 706, 172, 346, 952, 1259, 1831, 313, 1599, 1744]}, {"line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "NeuralProphet", "text": "", "type": "scatter", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-01-12", "2020-01-13", "2020-01-14", "2020-01-15", "2020-01-16", "2020-01-17", "2020-01-18", "2020-01-19", "2020-01-20", "2020-01-21", "2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30"], "y": [583.74560546875, 421.31365966796875, 941.505126953125, 977.5675048828125, 1079.819091796875, 980.9078369140625, 909.2901000976562, 933.7249755859375, 904.9319458007812, 935.773681640625, 971.8360595703125, 1074.087646484375, 975.1763916015625, 903.5586547851562, 927.9935913085938, 899.2005004882812, 930.042236328125, 966.1046142578125, 700.1322631835938, 1507.82080078125, 560.9450073242188, 922.2621459960938, 893.4690551757812, 924.3108520507812, 960.373046875, 1062.624755859375, 963.7135009765625, 892.0957641601562, 916.5306396484375, 887.7376098632812]}],                        {"legend": {"bgcolor": "#FFFFFF", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#FFFFFF", "plot_bgcolor": "#FFFFFF", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887" ...
# [2021-05-27 00:18:12,501] INFO | darts.models.torch_forecasting_model | Train dataset contains 214 samples.
# [2021-05-27 00:18:12,501] INFO | darts.models.torch_forecasting_model | Train dataset contains 214 samples.
# INFO:darts.models.torch_forecasting_model:Train dataset contains 214 samples.
# LSTM Model
# /Users/dkalifa/Desktop/GAN-Event/venv/lib/python3.8/site-packages/torch/nn/modules/rnn.py:57: UserWarning:
#
# dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Training loss: 0.0763
#   0%|          | 0/1 [01:50<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-1fc164193149> in <module>
#      19
#      20         res_prediction = test_models(test, test_name=leaf_name, start_pred_time=start_pred_time, train=train, use_cache=ts_cache)
# ---> 21         lstm_predictions = get_lstm_results(train, test, train_df, test_df, events_all, start_pred_time, leaf_name, peaks_data, n_in, window_size, events_dates, device, lstm_df_cache, lstm_cache)
#      22         tcn_predictions = get_tcn_results(train, test, train_df, test_df, events_all, start_pred_time, leaf_name, peaks_data, n_in, window_size, events_dates, device, tcn_df_cache, tcn_cache)
#      23         neural_predictions = get_neural_prophet_results(train, test, events_all, leaf_name, peaks_data, events_dates, start_pred_time, neural_cache)
#
# ~/Desktop/GAN-Event/src/demand_prediction/lstm_models.py in get_lstm_results(train, test, train_df, test_df, events_all, start_pred_time, leaf_name, peaks_data, n_in, window_size, events_dates, device, lstm_df_cache, use_cache)
#     105     lstm_predictions = []
#     106     for model in ['LSTM', 'Event LSTM', 'GAN - Event LSTM', 'Weighted Event LSTM']:
# --> 107         res_df, predictions = lstm_model_results(train, test, train_df, test_df, events_all, start_pred_time, leaf_name, peaks_data,
#     108                         n_in, model, window_size, events_dates, device=device, lstm_df_cache=lstm_df_cache, use_cache=use_cache)
#     109         lstm_results = lstm_results.append(res_df, ignore_index=True)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # Prediction Plot

# %%
total_pred = total_pred[total_pred.index >= start_pred_list[0]]

# %%
pred_df = total_pred[['Real Quantity', 'LSTM', 'GAN - Event LSTM', 'Event LSTM', 'Weighted Event LSTM', 'ARIMA', 'Prophet', 'NeuralProphet', 'GAN - Event CNN']]
pred_df.iplot(title = leaf_name + " - All Models", xTitle='Date', yTitle='Sales', theme='white')

# %%
# from sklearn.metrics import mean_squared_error, mean_absolute_error, ndcg_score

# def wmape(y_true, y_pred):
#     y_true, y_pred = np.array(y_true), np.array(y_pred)
#     return np.sum(np.abs(y_true - y_pred)) / np.sum(np.abs(y_true))

# total_pred = test_peaks.rename(columns={'Quantity': 'Real Quantity'}).merge(total_pred, left_index=True, right_index=True)

# %% [markdown]
# # Metrics@K

# %%
# res_str = ""
# for k in [5, 10, 20]:
#     pred_at_k = total_pred.iloc[total_pred['Real Quantity'].abs().argsort()][-k:]
#     mae_k = mean_absolute_error(pred_at_k['Real Quantity'], pred_at_k['GAN - Event LSTM'])
#     print("MAE@", str(k), ": ", int(round(mae_k)))
#     wmape_k = wmape(pred_at_k['Real Quantity'], pred_at_k['GAN - Event LSTM'])
#     print("wMAPE@", str(k), ": ", (round(wmape_k, 3)))
#     print("")
#     res_str = res_str + str(int(round(mae_k))) + " & " + str((round(wmape_k, 3))) + " & "
# print(res_str[:-2])

# %%
df_res = get_all_k_metrics(total_pred, peaks_data, final_list, leaf_name, start_pred_list, prediction_time)
df_res

# %% [markdown]
# # Plot@K

# %%
from demand_prediction.results_functions import plot_k_graph

k_plot = plot_k_graph(total_pred, peaks_data, final_list, leaf_name, start_pred_list, prediction_time, 'MAE').T
k_plot = k_plot.loc[['MAE@5', 'MAE@10', 'MAE@20', 'MAE@25']]
k_plot.iplot(title=leaf_name + " - MAE@K", xTitle='Date', yTitle='MAE', theme='white')
print(k_plot.idxmin(axis = 1))

k_plot = plot_k_graph(total_pred, peaks_data, final_list, leaf_name, start_pred_list, prediction_time, 'MAPE').T
k_plot = k_plot.loc[['MAPE@5', 'MAPE@10', 'MAPE@20', 'MAPE@25']]
k_plot.iplot(title=leaf_name + " - MAPE@K", xTitle='Date', yTitle='MAPE', theme='white')
print(k_plot.idxmin(axis = 1))


k_plot = plot_k_graph(total_pred, peaks_data, final_list, leaf_name, start_pred_list, prediction_time, 'MAPE').T
k_plot = k_plot.loc[['wMAPE@5', 'wMAPE@10', 'wMAPE@20', 'wMAPE@25']]
k_plot.iplot(title=leaf_name + " - wMAPE@K", xTitle='Date', yTitle='MAPE', theme='white')
print(k_plot.idxmin(axis = 1))
